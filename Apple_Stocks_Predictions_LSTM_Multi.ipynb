# %% [markdown]
# # Importing neccesary python modules

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from datetime import datetime
from datetime import timedelta
import tensorflow as tf

# %% [markdown]
# # Importing Dataset

# %%
# To Import Data from google drive (authentication needed)
from google.colab import drive 
drive.mount('/content/gdrive')
Data=pd.read_csv('gdrive/My Drive/Personal Data Science Projects/Apple Stocks Predictions/AAPL.csv', parse_dates=['Date'])
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###  Droppping Past Stocks data ( Data on year 2017 and less )

# %%
# Data.head()
# Data = Data[ Data['Date']>=datetime(2016,1,1) ]

# %% [markdown]
# ### Renaming the Data Column

# %%
Data['date'] = Data[['Date']]
Data['close'] = Data['Close']
Data.drop(columns=['Date','Close'],inplace=True)
df = Data.copy()

# %%
df
# Out:
#             Open        High         Low   Adj Close     Volume       date  \
# 0       7.622500    7.660714    7.585000    6.535085  493729600 2010-01-04
# 1       7.664286    7.699643    7.616071    6.546383  601904800 2010-01-05
# 2       7.656429    7.686786    7.526786    6.442257  552160000 2010-01-06
# 3       7.562500    7.571429    7.466071    6.430347  477131200 2010-01-07
# 4       7.510714    7.571429    7.466429    6.473095  447610800 2010-01-08
# ...          ...         ...         ...         ...        ...        ...
# 3121  137.389999  144.339996  137.139999  143.779999   90601500 2022-05-26
# 3122  145.389999  149.679993  145.259995  149.639999   90978500 2022-05-27
# 3123  149.070007  150.660004  146.839996  148.839996  103718400 2022-05-31
# 3124  149.899994  151.740005  147.679993  148.710007   74286600 2022-06-01
# 3125  147.830002  151.270004  146.860001  151.210007   72232000 2022-06-02
#
#            close
# 0       7.643214
# 1       7.656429
# 2       7.534643
# 3       7.520714
# 4       7.570714
# ...          ...
# 3121  143.779999
# 3122  149.639999
# 3123  148.839996
# 3124  148.710007
# 3125  151.210007
#
# [3126 rows x 7 columns]

# %% [markdown]
# # Visualization of the Data ( Close_Price vs Date )

# %%
fig = px.line( x = Data['date'],y=Data['close'] )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cab8ef64-a8fb-45e2-b7ad-60726b3fa841" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cab8ef64-a8fb-45e2-b7ad-60726b3fa841")) {                    Plotly.newPlot(                        "cab8ef64-a8fb-45e2-b7ad-60726b3fa841",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-01-19T00:00:00","2010-01-20T00:00:00","2010-01-21T00:00:00","2010-01-22T00:00:00","2010-01-25T00:00:00","2010-01-26T00:00:00","2010-01-27T00:00:00","2010-01-28T00:00:00","2010-01-29T00:00:00","2010-02-01T00:00:00","2010-02-02T00:00:00","2010-02-03T00:00:00","2010-02-04T00:00:00","2010-02-05T00:00:00","2010-02-08T00:00:00","2010-02-09T00:00:00","2010-02-10T00:00:00","2010-02-11T00:00:00","2010-02-12T00:00:00","2010-02-16T00:00:00","2010-02-17T00:00:00","2010-02-18T00:00:00","2010-02-19T00:00:00","2010-02-22T00:00:00","2010-02-23T00:00:00","2010-02-24T00:00:00","2010-02-25T00:00:00","2010-02-26T00:00:00","2010-03-01T00:00:00","2010-03-02T00:00:00","2010-03-03T00:00:00","2010-03-04T00:00:00","2010-03-05T00:00:00","2010-03-08T00:00:00","2010-03-09T00:00:00","2010-03-10T00:00:00","2010-03-11T00:00:00","2010-03-12T00:00:00","2010-03-15T00:00:00","2010-03-16T00:00:00","2010-03-17T00:00:00","2010-03-18T00:00:00","2010-03-19T00:00:00","2010-03-22T00:00:00","2010-03-23T00:00:00","2010-03-24T00:00:00","2010-03-25T00:00:00","2010-03-26T00:00:00","2010-03-29T00:00:00","2010-03-30T00:00:00","2010-03-31T00:00:00","2010-04-01T00:00:00","2010-04-05T00:00:00","2010-04-06T00:00:00","2010-04-07T00:00:00","2010-04-08T00:00:00","2010-04-09T00:00:00","2010-04-12T00:00:00","2010-04-13T00:00:00","2010-04-14T00:00:00","2010-04-15T00:00:00","2010-04-16T00:00:00","2010-04-19T00:00:00","2010-04-20T00:00:00","2010-04-21T00:00:00","2010-04-22T00:00:00","2010-04-23T00:00:00","2010-04-26T00:00:00","2010-04-27T00:00:00","2010-04-28T00:00:00","2010-04-29T00:00:00","2010-04-30T00:00:00","2010-05-03T00:00:00","2010-05-04T00:00:00","2010-05-05T00:00:00","2010-05-06T00:00:00","2010-05-07T00:00:00","2010-05-10T00:00:00","2010-05-11T00:00:00","2010-05-12T00:00:00","2010-05-13T00:00:00","2010-05-14T00:00:00","2010-05-17T00:00:00","2010-05-18T00:00:00","2010-05-19T00:00:00","2010-05-20T00:00:00","2010-05-21T00:00:00","2010-05-24T00:00:00","2010-05-25T00:00:00","2010-05-26T00:00:00","2010-05-27T00:00:00","2010-05-28T00:00:00","2010-06-01T00:00:00","2010-06-02T00:00:00","2010-06-03T00:00:00","2010-06-04T00:00:00","2010-06-07T00:00:00","2010-06-08T00:00:00","2010-06-09T00:00:00","2010-06-10T00:00:00","2010-06-11T00:00:00","2010-06-14T00:00:00","2010-06-15T00:00:00","2010-06-16T00:00:00","2010-06-17T00:00:00","2010-06-18T00:00:00","2010-06-21T00:00:00","2010-06-22T00:00:00","2010-06-23T00:00:00","2010-06-24T00:00:00","2010-06-25T00:00:00","2010-06-28T00:00:00","2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08- ...

# %% [markdown]
# ***
# ***
# # Multivariate Time Series Predictions using LTSM

# %%
df_date = df[['date']]
df_close = df[['close']]
df.drop(columns=['date'],inplace=True)
df.head()
# Out:
#        Open      High       Low  Adj Close     Volume     close
# 0  7.622500  7.660714  7.585000   6.535085  493729600  7.643214
# 1  7.664286  7.699643  7.616071   6.546383  601904800  7.656429
# 2  7.656429  7.686786  7.526786   6.442257  552160000  7.534643
# 3  7.562500  7.571429  7.466071   6.430347  477131200  7.520714
# 4  7.510714  7.571429  7.466429   6.473095  447610800  7.570714

# %% [markdown]
# # Scaling the all the features
# ### Last scaler of this for loop is of column 'close' which we need later for inverse scaling

# %%
from sklearn.preprocessing import StandardScaler
for feature in list(df.columns.values):
  scaler = StandardScaler()
  scaler.fit( df[[feature]] )
  df[feature] = scaler.transform( df[[feature]] )

# %% [markdown]
# # Defining a function to create Timestaped Data Matrix in which window size can be given as input
#
# ### This function includes all the feature available for creating matrix unlike in case of Univariate (where we use only one column i.e 'Close Price' )

# %%
def Create_Timestaped_Data_Matrix_Multi( df, size ):
  X,y,dates = [],[],[]
  for i in range(df.shape[0]-size):
    X.append( np.asarray(df.values[i:i+size]).astype(np.float64) )
    y.append( df['close'].values[i+size] )
    dates.append(df_date['date'][i+size])
  return np.array(X), np.array(y), dates

window_size = 50
X,y,dates = Create_Timestaped_Data_Matrix_Multi( df, size=window_size )

# %%
X.shape, y.shape
# Out:
# ((3076, 50, 6), (3076,))

# %% [markdown]
# # Train-Test-Split

# %%
test_size_ratio = 0.1
train_size = int((1-test_size_ratio)*len(y))
# Train Set
y_train = y[:train_size]
dates_train = dates[:train_size]
y_test = y[train_size:]
X_train = X[:train_size] 
# Test Set
dates_test = dates[train_size:]
X_test = X[train_size:]
y_train_original = Data['close'][window_size:train_size+window_size] # Storing original columns for plotting graph
y_test_original = Data['close'][train_size+window_size:] # Storing original columns for plotting graph
# Check length
# len(y_train)+len(y_test),len(y)

# %%
## Splitting data according a particular date ( "split_date" )
# import datetime as dt
# split_date = df['date'][1100]
# split_date

# test = Data[ Data['date']>=split_date]
# train = Data[ Data['date']<Jan2019 ]
# test_date = Data[ Data['date']>=Jan2019].values
# train_date = Data[ Data['date']<Jan2019 ].values
# train.shape, test.shape

# X_train, y_train = Create_Timestaped_Data_Matrix( train, size=50 )
# X_test, y_test = Create_Timestaped_Data_Matrix( test, size=50 )

# %% [markdown]
# ### Graph of Splitted Data

# %%
fig = go.Figure()
fig.add_trace( go.Scatter( x=dates_train, y=y_train,mode='lines', name="Train Set" ) )
fig.add_trace( go.Scatter( x=dates_test, y=y_test,mode='lines', name="Test Set" ) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9fc61d99-5fa3-4c8c-93f1-c8b35a83f226" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fc61d99-5fa3-4c8c-93f1-c8b35a83f226")) {                    Plotly.newPlot(                        "9fc61d99-5fa3-4c8c-93f1-c8b35a83f226",                        [{"mode":"lines","name":"Train Set","x":["2010-03-17T00:00:00","2010-03-18T00:00:00","2010-03-19T00:00:00","2010-03-22T00:00:00","2010-03-23T00:00:00","2010-03-24T00:00:00","2010-03-25T00:00:00","2010-03-26T00:00:00","2010-03-29T00:00:00","2010-03-30T00:00:00","2010-03-31T00:00:00","2010-04-01T00:00:00","2010-04-05T00:00:00","2010-04-06T00:00:00","2010-04-07T00:00:00","2010-04-08T00:00:00","2010-04-09T00:00:00","2010-04-12T00:00:00","2010-04-13T00:00:00","2010-04-14T00:00:00","2010-04-15T00:00:00","2010-04-16T00:00:00","2010-04-19T00:00:00","2010-04-20T00:00:00","2010-04-21T00:00:00","2010-04-22T00:00:00","2010-04-23T00:00:00","2010-04-26T00:00:00","2010-04-27T00:00:00","2010-04-28T00:00:00","2010-04-29T00:00:00","2010-04-30T00:00:00","2010-05-03T00:00:00","2010-05-04T00:00:00","2010-05-05T00:00:00","2010-05-06T00:00:00","2010-05-07T00:00:00","2010-05-10T00:00:00","2010-05-11T00:00:00","2010-05-12T00:00:00","2010-05-13T00:00:00","2010-05-14T00:00:00","2010-05-17T00:00:00","2010-05-18T00:00:00","2010-05-19T00:00:00","2010-05-20T00:00:00","2010-05-21T00:00:00","2010-05-24T00:00:00","2010-05-25T00:00:00","2010-05-26T00:00:00","2010-05-27T00:00:00","2010-05-28T00:00:00","2010-06-01T00:00:00","2010-06-02T00:00:00","2010-06-03T00:00:00","2010-06-04T00:00:00","2010-06-07T00:00:00","2010-06-08T00:00:00","2010-06-09T00:00:00","2010-06-10T00:00:00","2010-06-11T00:00:00","2010-06-14T00:00:00","2010-06-15T00:00:00","2010-06-16T00:00:00","2010-06-17T00:00:00","2010-06-18T00:00:00","2010-06-21T00:00:00","2010-06-22T00:00:00","2010-06-23T00:00:00","2010-06-24T00:00:00","2010-06-25T00:00:00","2010-06-28T00:00:00","2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-10T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","20 ...

# %%
# # Reshaping and converting splited data into Dataframe for next step
# X_train = X_train.reshape(X_train.shape[0],X_train.shape[1])
# X_test = X_test.reshape(X_test.shape[0],X_test.shape[1])
# X_train = pd.DataFrame( X_train )
# X_test = pd.DataFrame( X_test )

# %% [markdown]
# # Applying LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
model = Sequential()
model.add( LSTM( 500, return_sequences =True, input_shape=(50,6) ) )
model.add( LSTM(100) ) 
model.add( Dense(1) )
model.compile( loss='mean_squared_error', optimizer='adam' )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 500)           1014000
#
#  lstm_1 (LSTM)               (None, 100)               240400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 1,254,501
# Trainable params: 1,254,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train,validation_data = (X_test,y_test), epochs=25 , verbose=1)
# Out:
# Epoch 1/25
# 87/87 [==============================] - 9s 21ms/step - loss: 0.0092 - val_loss: 0.0638
# Epoch 2/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 0.0136
# Epoch 3/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0180
# Epoch 4/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0092
# Epoch 5/25
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 0.0619
# Epoch 6/25
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 0.0779
# Epoch 7/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0337
# Epoch 8/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 0.0242
# Epoch 9/25
# 87/87 [==============================] - 1s 11ms/step - loss: 9.5852e-04 - val_loss: 0.0105
# Epoch 10/25
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 11/25
# 87/87 [==============================] - 1s 11ms/step - loss: 8.7354e-04 - val_loss: 0.0156
# Epoch 12/25
# 87/87 [==============================] - 1s 12ms/step - loss: 7.5826e-04 - val_loss: 0.0060
# Epoch 13/25
# 87/87 [==============================] - 1s 11ms/step - loss: 9.7653e-04 - val_loss: 0.0057
# Epoch 14/25
# 87/87 [==============================] - 1s 11ms/step - loss: 9.4089e-04 - val_loss: 0.0067
# Epoch 15/25
# 87/87 [==============================] - 1s 11ms/step - loss: 7.7313e-04 - val_loss: 0.0199
# Epoch 16/25
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3119e-04 - val_loss: 0.0120
# Epoch 17/25
# 87/87 [==============================] - 1s 11ms/step - loss: 8.3864e-04 - val_loss: 0.0187
# Epoch 18/25
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3045e-04 - val_loss: 0.0076
# Epoch 19/25
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3757e-04 - val_loss: 0.0053
# Epoch 20/25
# 87/87 [==============================] - 1s 11ms/step - loss: 7.2158e-04 - val_loss: 0.0047
# Epoch 21/25
# 87/87 [==============================] - 1s 12ms/step - loss: 7.2488e-04 - val_loss: 0.0381
# Epoch 22/25
# 87/87 [==============================] - 1s 11ms/step - loss: 9.2860e-04 - val_loss: 0.0083
# Epoch 23/25
# 87/87 [==============================] - 1s 12ms/step - loss: 7.7656e-04 - val_loss: 0.0141
# Epoch 24/25
# 87/87 [==============================] - 1s 12ms/step - loss: 7.3800e-04 - val_loss: 0.0232
# Epoch 25/25
# 87/87 [==============================] - 1s 11ms/step - loss: 6.9489e-04 - val_loss: 0.0137

# %% [markdown]
# ### Saving the model

# %%
model.save('/content/APPL_multivariate_lstm.h5')

# %% [markdown]
# ###  Fucntion defined to change the shape of  Data ( from reshape(-1,1) to   )

# %%
def changing_shape( array ):
  temp = []
  for i in range(len(array)):
    temp.append(array[i][0])
  return temp

# %% [markdown]
# ### Function defined for making Prediction using the model trained above, then apply inverse scaling and then changing the shape of output array

# %%
def Prediction_Inverse_Scaling_Reshaping( model, X_train, X_test ):
  # Predicting values and Appyling Inverse Scaler
  y_pred = model.predict( X_test )
  y_pred = scaler.inverse_transform( y_pred )

  y_pred_train = model.predict( X_train )
  y_pred_train = scaler.inverse_transform( y_pred_train )

  # Reshaping
  y_pred = changing_shape(y_pred)
  y_pred_train = changing_shape( y_pred_train )

  return y_pred, y_pred_train


y_pred, y_pred_train = Prediction_Inverse_Scaling_Reshaping( model, X_train, X_test )

# %%
fig = go.Figure()
fig.add_trace( go.Scatter( x=dates_train, y=y_train_original,mode='lines', name="Original Train Set" ) )
fig.add_trace( go.Scatter( x=dates_test, y=y_test_original,mode='lines', name="Original Test Set" ) )
fig.add_trace( go.Scatter( x=dates_train, y=y_pred_train, name="Predicted Train Set" ) )
fig.add_trace( go.Scatter( x=dates_test, y=y_pred,mode='lines', name="Predicted Test Set" ) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1f891f00-fd3c-4260-ae56-d1a703dbca72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f891f00-fd3c-4260-ae56-d1a703dbca72")) {                    Plotly.newPlot(                        "1f891f00-fd3c-4260-ae56-d1a703dbca72",                        [{"mode":"lines","name":"Original Train Set","x":["2010-03-17T00:00:00","2010-03-18T00:00:00","2010-03-19T00:00:00","2010-03-22T00:00:00","2010-03-23T00:00:00","2010-03-24T00:00:00","2010-03-25T00:00:00","2010-03-26T00:00:00","2010-03-29T00:00:00","2010-03-30T00:00:00","2010-03-31T00:00:00","2010-04-01T00:00:00","2010-04-05T00:00:00","2010-04-06T00:00:00","2010-04-07T00:00:00","2010-04-08T00:00:00","2010-04-09T00:00:00","2010-04-12T00:00:00","2010-04-13T00:00:00","2010-04-14T00:00:00","2010-04-15T00:00:00","2010-04-16T00:00:00","2010-04-19T00:00:00","2010-04-20T00:00:00","2010-04-21T00:00:00","2010-04-22T00:00:00","2010-04-23T00:00:00","2010-04-26T00:00:00","2010-04-27T00:00:00","2010-04-28T00:00:00","2010-04-29T00:00:00","2010-04-30T00:00:00","2010-05-03T00:00:00","2010-05-04T00:00:00","2010-05-05T00:00:00","2010-05-06T00:00:00","2010-05-07T00:00:00","2010-05-10T00:00:00","2010-05-11T00:00:00","2010-05-12T00:00:00","2010-05-13T00:00:00","2010-05-14T00:00:00","2010-05-17T00:00:00","2010-05-18T00:00:00","2010-05-19T00:00:00","2010-05-20T00:00:00","2010-05-21T00:00:00","2010-05-24T00:00:00","2010-05-25T00:00:00","2010-05-26T00:00:00","2010-05-27T00:00:00","2010-05-28T00:00:00","2010-06-01T00:00:00","2010-06-02T00:00:00","2010-06-03T00:00:00","2010-06-04T00:00:00","2010-06-07T00:00:00","2010-06-08T00:00:00","2010-06-09T00:00:00","2010-06-10T00:00:00","2010-06-11T00:00:00","2010-06-14T00:00:00","2010-06-15T00:00:00","2010-06-16T00:00:00","2010-06-17T00:00:00","2010-06-18T00:00:00","2010-06-21T00:00:00","2010-06-22T00:00:00","2010-06-23T00:00:00","2010-06-24T00:00:00","2010-06-25T00:00:00","2010-06-28T00:00:00","2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-10T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:0 ...

# %%
from sklearn.metrics import mean_squared_error
np.sqrt( mean_squared_error( y_pred, y_test_original ) )
# Out:
# 5.079044246279781

# %% [markdown]
# # Prediction for Next Days

# %%
# Extracting last values values (of certain window size) from the df to use it for predicting stock price for next date
last = df.iloc[-window_size:].values 
pred_close = model.predict( last.reshape( 1, window_size, 6 ) )[0][0]
pred_close = scaler.inverse_transform( pred_close.reshape(-1,1) )[0][0]

# Adding one day to last date ( for adding "next" day date )
temp_date = dates_test[-1] + timedelta(days=1)

# Creating dataframe of 'next' and prediction on that day then appending them to df
future_pred_df =pd.DataFrame({'date':[temp_date],'close':[pred_close]})

# %%
future_pred_df
# Out:
#         date       close
# 0 2022-06-03  147.182571
